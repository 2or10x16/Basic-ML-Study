# %% [markdown]
# ### 앙상블 학습
#
# 여러개의 분류기를 생성하고 그 예측을 결합함으로써 보다 정확한 최종 예측 도출

# %% [markdown]
# #### 특징
#
# * 단일 모델 약점을 다수 모델 결합으로 보완
# * 결정 트리 알고리즘 기반
# * 결정트리 단점 보완하고 장점 강화

# %% [markdown]
# * 보팅
#  -서로 다른 알고리즘을 가진 분류기 결합
#
#
# * 배깅
#  -각각의 분류기가 모두 같은 유형이지만 데이터 샘플링 서로 다르게 학습
#  -ex)랜덤 포레스트
#
#
# * 부스팅
#  -여러개의 약한 학습기를 순차적으로 학습,예측하며 잘못 예측한 데이터에 가중치 부여하며 오류 개선

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 배깅
#
# N개의 학습 데이터 세트에서 k개를 임의로 선택해서 랜덤트리 만드는 것
#
# -중복 허용함

# %% [markdown]
# 각 분할에서 전체 속성들 중 "일부만" 고려해 트리 작성하도록 함
# => 전체 속성의 제곱근 만큼 선택하는게 제일 좋음

# %% [markdown]
# ### 랜덤 포레스트
#
# 여러개의 결정 트리 분류기가 전체 데이터에서 배깅 방식으로 각자의 데이터를 샘플링해 개별적으로 학습을 수행한 뒤 최종적으로 모든 분류기가 보팅을 통해 예측 결정
#
# ∴훈련을 통해 구성해놓은 다수의 트리로들로부터 분류 결과 취합해서 결론 얻는 것

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 부트스트래핑 방식
#
# =여러개의 데이터 세트를 중첩되게 분리
#
# -랜덤 포레스트의 서브세트 데이터는 부트스트래핑으로 만들어져 중첩되어 만들어짐

# %% [markdown]
# ![image.png](attachment:image.png)
